# %% [markdown]
# <a href="https://colab.research.google.com/github/KhoaKD59/MID-TERM---MINI-PROJECT/blob/main/10Foods_vietnamese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google. colab                 import drive
from matplotlib.image              import imread
from os                            import listdir
from numpy                         import asarray
from numpy                         import save
from keras.utils                   import load_img
from keras.utils                   import img_to_array
from keras.models                  import Sequential
from keras.layers                  import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.utils        import load_img, img_to_array
from google.colab                  import drive
import matplotlib.pyplot as plt
import numpy as np

# %%
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/AI_PROJECT/10FoodVN/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('banh_bo'):
     output = 0
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos.append(photo)
     labels.append(output)

  elif file.startswith('banh_bot_loc'):
     output = 1
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos.append(photo)
     labels.append(output)

  elif file.startswith('banh_cong'):
    output = 2
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

  elif file.startswith('banh_da_lon'):
    output = 3
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

  elif file.startswith('banh_khot'):
    output = 4
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
  elif file.startswith('banh_mi'):
    output = 5
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append (output)
  elif file.startswith('banh_tai_heo'):
    output = 6
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
  elif file.startswith('banh_tieu'):
    output = 7
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
  elif file.startswith('banh_trung_thu'):
    output = 8
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

  elif file.startswith('banh_xeo'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (474, 200, 200, 3) (474,)

# %%
print(photos.shape)
print(labels.shape)
# Out:
# (474, 200, 200, 3)
# (474,)

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu',
kernel_initializer='he_uniform',
padding='same',
input_shape=(200,200, 3)))

model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu',
kernel_initializer='he_uniform',
padding='same'))

model. add(MaxPooling2D((2, 2)))

model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu',
kernel_initializer='he_uniform',
padding='same' ))

model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dropout (0.2) )

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='Adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos,labels, batch_size =64, epochs=20, verbose=1)
model.save('10foods.h5')
classes = ["banh_bo","banh_bot_loc","banh_cong","banh_da_lon","banh_khot","banh_mi","banh_tai_heo","banh_tieu","banh_trung_thu","banh_xeo"]
# Out:
# Epoch 1/20
# 8/8 [==============================] - 3s 130ms/step - loss: 4377.3022 - accuracy: 0.1055
# Epoch 2/20
# 8/8 [==============================] - 1s 123ms/step - loss: 61.0232 - accuracy: 0.1181
# Epoch 3/20
# 8/8 [==============================] - 1s 123ms/step - loss: 4.1214 - accuracy: 0.1603
# Epoch 4/20
# 8/8 [==============================] - 1s 122ms/step - loss: 2.6819 - accuracy: 0.1414
# Epoch 5/20
# 8/8 [==============================] - 1s 129ms/step - loss: 2.3835 - accuracy: 0.1751
# Epoch 6/20
# 8/8 [==============================] - 1s 128ms/step - loss: 2.2390 - accuracy: 0.1751
# Epoch 7/20
# 8/8 [==============================] - 1s 129ms/step - loss: 2.2229 - accuracy: 0.2025
# Epoch 8/20
# 8/8 [==============================] - 1s 126ms/step - loss: 2.1327 - accuracy: 0.2110
# Epoch 9/20
# 8/8 [==============================] - 1s 123ms/step - loss: 2.0942 - accuracy: 0.2046
# Epoch 10/20
# ...

# %%
img = load_img('banhmitest.jpg', target_size=(200,200))
plt .imshow(img)

imgRe = img_to_array(img)

imgRe = imgRe.reshape(1,200, 200, 3)

imgRe = imgRe.astype('float32')

imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)

y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 94ms/step
# [[0.11282412 0.08114424 0.10398895 0.10231943 0.09386385 0.07519593
#   0.11365289 0.10979586 0.10786659 0.09934818]]
# 'banh_tai_heo'
