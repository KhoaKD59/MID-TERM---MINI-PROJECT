# %% [markdown]
# <a href="https://colab.research.google.com/github/KhoaKD59/MID-TERM---MINI-PROJECT/blob/main/10Foods_Vietnam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google. colab                 import drive
from matplotlib.image              import imread
from os                            import listdir
from numpy                         import asarray
from numpy                         import save
from keras.utils                   import load_img
from keras.utils                   import img_to_array
from keras.models                  import Sequential
from keras.layers                  import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.utils        import load_img, img_to_array
from google.colab                  import drive
import matplotlib.pyplot as plt
import numpy as np

# %%
folder= '/content/drive/MyDrive/AI_PROJECT/Money/'

photos, labels = list(), list()
for file in listdir(folder):
   if file.startswith('dollar'):
     output = 0
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos. append(photo)
     labels. append (output)
for file in listdir(folder):
   if file.startswith( 'haimuoingandong'):
     output = 1
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos. append(photo)
     labels. append (output)
for file in listdir(folder):
   if file.startswith( 'haingandong'):
     output =  2
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos. append(photo)
     labels. append (output)
for file in listdir(folder):
   if file.startswith( 'haitramngandong'):
    output = 3
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)


for file in listdir(folder):
   if file.startswith('Malaysia'):
    output = 4
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
for file in listdir(folder):
   if file.startswith('motngandong'):
    output = 5
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
for file in listdir(folder):
   if file.startswith('mottramngandong'):
     output = 6
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos.append(photo)
     labels.append(output)
for file in listdir(folder):
   if file.startswith('muoingandong'):
    output = 7
    photo = load_img(folder+file, target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
for file in listdir(folder):
   if file.startswith( 'namngandong'):
     output = 9
     photo = load_img(folder+file, target_size=(200,200))
     photo = img_to_array(photo)
     photos.append(photo)
     labels.append(output)
photos = asarray(photos)
labels = asarray(labels)

# %%
print(photos.shape)
print(labels.shape)
# Out:
# (421, 200, 200, 3)
# (421,)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation= 'relu',
                 kernel_initializer= 'he_uniform',
                 padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu',
                 kernel_initializer= 'he_uniform',
                 padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu',
                 kernel_initializer= 'he_uniform',
                 padding='same'))
model.add(MaxPooling2D((2, 2)) )
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(128, activation= 'relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.compile(optimizer='Adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos,labels, batch_size =64, epochs=20, verbose=1)
model.save('10moneys.h5')
classes = ["dollar","haimuoingandong","haingandong","Malaysia","mottramngandong","motngandong","muoingandong","namngan","nammuoingan","haitramngandong"]
# Out:
# Epoch 1/20
# 7/7 [==============================] - 16s 284ms/step - loss: 2044.8182 - accuracy: 0.1496
# Epoch 2/20
# 7/7 [==============================] - 1s 128ms/step - loss: 210.6631 - accuracy: 0.1615
# Epoch 3/20
# 7/7 [==============================] - 1s 128ms/step - loss: 2.9067 - accuracy: 0.2138
# Epoch 4/20
# 7/7 [==============================] - 1s 127ms/step - loss: 2.1156 - accuracy: 0.2470
# Epoch 5/20
# 7/7 [==============================] - 1s 128ms/step - loss: 1.9001 - accuracy: 0.2803
# Epoch 6/20
# 7/7 [==============================] - 1s 131ms/step - loss: 0.9612 - accuracy: 0.6722
# Epoch 7/20
# 7/7 [==============================] - 1s 131ms/step - loss: 0.3551 - accuracy: 0.8931
# Epoch 8/20
# 7/7 [==============================] - 1s 134ms/step - loss: 0.1559 - accuracy: 0.9596
# Epoch 9/20
# 7/7 [==============================] - 1s 134ms/step - loss: 0.1872 - accuracy: 0.9525
# Epoch 10/20
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0817 - accuracy: 0.9644
# Epoch 11/20
# 7/7 [==============================] - 1s 128ms/step - loss: 0.1132 - accuracy: 0.9620
# Epoch 12/20
# 7/7 [==============================] - 1s 127ms/step - loss: 0.0925 - accuracy: 0.9810
# Epoch 13/20
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0734 - accuracy: 0.9786
# Epoch 14/20
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0473 - accuracy: 0.9810
# Epoch 15/20
# 7/7 [==============================] - 1s 128ms/step - loss: 0.1049 - accuracy: 0.9762
# Epoch 16/20
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0650 - accuracy: 0.9786
# Epoch 17/20
# 7/7 [==============================] - 1s 128ms/step - loss: 0.0429 - accuracy: 0.9905
# Epoch 18/20
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0919 - accuracy: 0.9762
# Epoch 19/20
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0848 - accuracy: 0.9739
# Epoch 20/20
# 7/7 [==============================] - 1s 128ms/step - loss: 0.1420 - accuracy: 0.9786

# %%
img = load_img('100ktest.jpg', target_size=(200,200))
plt. imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print (y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# 1/1 [==============================] - 0s 345ms/step
# [[0.09611083 0.09723738 0.11656273 0.10090413 0.11992297 0.10228346
#   0.09508665 0.10025829 0.07686734 0.09476629]]
# 'mottramngandong'
